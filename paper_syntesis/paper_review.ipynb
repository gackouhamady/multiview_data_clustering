# %% [markdown]
# ###  📘 Papiers fondamentaux (3 à 5)
#
# Ces articles posent les bases du clustering multivue, introduisant des concepts clés et des approches pionnières.
# #### 1. [Simultaneous Linear Multi-view Attributed Graph Representation Learning and Clustering ]( https://dl.acm.org/doi/10.1145/3539597.3570367)
#  Chakib Fettal  , Lazhar Labiod ,  Mohamed Nadif , WSDM  2023
#
# #### 2. [Efficient Graph Convolution for Joint Node Representation Learning and Clustering](https://dl.acm.org/doi/10.1145/3488560.3498533)
#  Chakib Fettal  , Lazhar Labiod ,  Mohamed Nadif , WSDM  2023
#
#
# #### 3 [High-dimensional multi-view clustering methods](https://arxiv.org/abs/2303.08582)
# *Zahir et al., 2023*
# Une revue complète des méthodes de clustering multivue, mettant l'accent sur les approches basées sur les graphes et les sous-espaces, avec une attention particulière aux représentations tensorielles pour capturer les corrélations de haut ordre.
#
# #### 4 [Multi-view Clustering via Deep Matrix Factorization and Partition Alignment](https://arxiv.org/abs/2105.00277)
# *Zhang et al., 2021*
# Propose une méthode de factorisation matricielle profonde pour le clustering multivue, combinant l'alignement des partitions et l'apprentissage de représentations spécifiques à chaque vue.
#
# #### 5 [High-order Multi-view Clustering for Generic Data](https://arxiv.org/abs/2209.10838)
# *Pan & Kang, 2022*
# Introduit une approche de clustering multivue exploitant les relations de voisinage de haut ordre pour enrichir la structure des graphes appris, applicable aux données avec ou sans structure de graphe initiale.
#
# ---
#
# ###  🚀 Papiers récents ou concurrents (5 à 7)
#
# Ces travaux récents (2023–2025) proposent des méthodes avancées ou concurrentes dans le domaine du clustering multivue.
#
# #### 1. [Structure-guided Deep Multi-View Clustering](https://chatpaper.com/chatpaper/fr/paper/101128)
# *Cui et al., 2025*
# Présente une méthode de clustering profond guidée par la structure, utilisant des graphes de plus proches voisins multi-vues et des distributions gaussiennes pour améliorer la cohérence entre les vues.
#
# #### 2. [Discriminative Anchor Learning for Efficient Multi-view Clustering](https://chatpaper.com/chatpaper/fr/paper/61656)
# *Qin et al., 2024*
# Propose un apprentissage discriminatif des ancres pour le clustering multivue, intégrant l'apprentissage des caractéristiques spécifiques à chaque vue et la construction d'un graphe d'ancres consensuel.
#
# #### 3. [Efficient Multi-View Graph Clustering with Local and Global Structure Preservation](https://simplescience.ai/fr/2023-08-31-avancees-dans-les-techniques-de-clustering-de-graphes-multi-vues--akz4z1)
# *Anonyme, 2023*
# Développe une méthode de clustering de graphes multivue efficace, préservant à la fois les structures locales et globales, avec une complexité linéaire par rapport au nombre d'échantillons.
#
# #### 4. [Scalable Incomplete Multi-View Clustering with Structure Alignment](https://simplescience.ai/fr/2023-08-31-avancees-dans-le-clustering-multi-vues-incomplet--a64xd7)
# *Anonyme, 2023*
# Aborde le clustering multivue incomplet en proposant un cadre d'apprentissage de graphes d'ancres avec alignement de structure, traitant les problèmes d'alignement des ancres et de disparité entre les vues.
#
# #### 5. [Rectified Gaussian kernel multi-view k-means clustering](https://arxiv.org/abs/2405.05619)
# *Sinaga, 2024*
# Introduit deux variantes du k-means multivue utilisant des noyaux gaussiens rectifiés pour améliorer la robustesse et l'efficacité du clustering sur des données multivues réelles.
#
# ---
#
# ###  🔍 Travaux connexes ou exploratoires (3 à 5)
#
# Ces travaux apportent des perspectives complémentaires ou explorent des idées transversales pertinentes pour le clustering multivue.
#
# #### 1. [Deep Multi-CoClustering des Données Multi-vues et Multimodales](https://theses.fr/s355627)
# *Khoufache, 2023*
# Projet de thèse explorant le co-clustering profond des données multivues et multimodales, avec une attention particulière à la scalabilité et à l'intégration de modèles topologiques.
#
# #### 2. [Un algorithme distribué pour le clustering de grands graphes](https://www.academia.edu/84566278/Un_algorithme_distribu%C3%A9_pour_le_clustering_de_grands_graphes)
# *Inoubli et al., 2020*
# Propose un algorithme distribué pour le clustering de grands graphes, pertinent pour le traitement de données multivues à grande échelle.
